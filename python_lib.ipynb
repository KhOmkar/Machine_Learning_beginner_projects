# %%
# !git clone https://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@github.com/KhOmkar/Machine_Learning_beginner_projects
# Out:
# Cloning into 'Machine_Learning_beginner_projects'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 21 (delta 1), reused 5 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (21/21), 4.74 MiB | 11.27 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
# !cd Machine_Learning_beginner_projects

# %%
# !git config --global user.email "itsomkar.dev@gmail.com"
# !git config --global user.name "Omkar K"

# %%
# !cp /content/drive/MyDrive/Colab Notebooks/python_lib.ipynb /content/Machine_Learning_beginner_projects/
# Out:
# cp: cannot stat '/content/drive/MyDrive/Colab': No such file or directory
# cp: cannot stat 'Notebooks/python_lib.ipynb': No such file or directory
